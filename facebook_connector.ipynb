# %% [markdown]
# # Facebook Connector

# %% [markdown]
# #### How to implement a facebook connector
# To implement a facebook connector we must know below things -
# #### 1. Graph API
# The Graph API is primary method to access means read and write data on facebook social graph. It has 3 components -
# ##### a) Node:
#         Nodes are individual objects such as user, page, photo and comment. we use nodes to gather data regarding
#         an individual object.
# ##### b) Edges:
#         Edges represents the connection between collection of objects to a single object. It can be used to publish
#         the single object to Collection of objects or get a collection of objects which are connected to a single
#         object. Suppose, A photo is posted in a person's facebook profile. Now, the comments associated with that photo
#         is the collection of objects and the photo itself is an individual object.
# ##### c) Fields:
#         Fields are used to represent data or Information about the an object. For example, for a Node User,
#         Date of birth, user age are associated fields. fields are used to specify a data that are required to
#         be included in the response.
# Since Graph API is HTTP based, it works with any language that has HTTP based library like curl, urllib etc. All requests are passed through the graphs.facebook.com host URL. (graph-video.facebook.com is an exception)
#
# Since nodes are individual objects, each node has its associated unique ID. Every user, page, photo has its unique ID associated with it.
#
# We Use access tokens to query data from facebook social graph. The access token grants app the permission to access data without user's credentials and also it allows the server to identify who is using the app and accordindly determine what function that user is permitted to do.

# %%
# !pip install facebook-sdk
# Out:
# Collecting facebook-sdk
#   Using cached facebook_sdk-3.1.0-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: requests in c:\users\skish\anaconda3\lib\site-packages (from facebook-sdk) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\skish\anaconda3\lib\site-packages (from requests->facebook-sdk) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\skish\anaconda3\lib\site-packages (from requests->facebook-sdk) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\skish\anaconda3\lib\site-packages (from requests->facebook-sdk) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\skish\anaconda3\lib\site-packages (from requests->facebook-sdk) (2.10)
# Installing collected packages: facebook-sdk
# Successfully installed facebook-sdk-3.1.0

# %%
import facebook
import json

# %%
### Getting Information from Personal User Account

import json
import facebook

def main():
    token = "EAAO76VF7KUsBAPceIbYieJBGW01xS2f2csWI7TUrI5p35xeXc7QPmHuTvQCQZCNzCTDtshZBDGrMEtawlcjKEXSOgCbVQwrPkoPGJajGcPPuVkBZAfpRdxH9Wp7cuMSxtHTRtOFiKXdZAqeGFdcEuKjgxvx2vwCVs5HNwuGzFqM3mmZB8HqPmoHBX1xYakElqWJPO7GaYZAxWrgXwLYtIHRzPD5ZBObbJ4ZD"
    graph = facebook.GraphAPI(token)
    post = graph.get_object('me',fields = "first_name,last_name,email,accounts")
    print(json.dumps(post, indent = 4))
if __name__ == '__main__':
    main()
# Out:
# {
#     "first_name": "Sk Ishan",
#     "last_name": "Ali",
#     "email": "skishanali981@gmail.com",
#     "accounts": {
#         "data": [
#             {
#                 "access_token": "EAAO76VF7KUsBACFhgPer5D2PvAmqou79tGzR6jPIIEAJ85T1IqDhtssa3wHE0FniGplSEXOM0LFZBwEZBtaxv5ICsMo9kC8PxukgaVZCfFWihWVZB8cZAVg2Gz9ljbPuPHOp6hfZCWY9ZAF1PVZCkZBs3hPl4K4B4SSDiXTFsERL9LOKqZCoZBfxuevZCVwhZC5TMPssbZBaaYBJf4BCbRXXDk58rp",
#                 "category": "Software company",
#                 "category_list": [
#                     {
#                         "id": "1065597503495311",
#                         "name": "Software company"
#                     }
#                 ],
#                 "name": "My test page",
#                 "id": "112591734873647",
#                 "tasks": [
#                     "ANALYZE",
#                     "ADVERTISE",
#                     "MESSAGING",
#                     "MODERATE",
#                     "CREATE_CONTENT",
#                     "MANAGE"
#                 ]
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "before": "MTEyNTkxNzM0ODczNjQ3",
#                 "after": "MTEyNTkxNzM0ODczNjQ3"
#             }
#         }
#     },
#     "id": "111497241650239"
# }

# %%
### Getting Information from Pages

def main():
    token = "EAAO76VF7KUsBAPceIbYieJBGW01xS2f2csWI7TUrI5p35xeXc7QPmHuTvQCQZCNzCTDtshZBDGrMEtawlcjKEXSOgCbVQwrPkoPGJajGcPPuVkBZAfpRdxH9Wp7cuMSxtHTRtOFiKXdZAqeGFdcEuKjgxvx2vwCVs5HNwuGzFqM3mmZB8HqPmoHBX1xYakElqWJPO7GaYZAxWrgXwLYtIHRzPD5ZBObbJ4ZD"
    graph = facebook.GraphAPI(token)
    post = graph.get_object('112591734873647', fields = "name, about, category, feed,posts, can_post")
    print(json.dumps(post, indent = 4))
if __name__ == '__main__':
    main()
# Out:
# {
#     "name": "My test page",
#     "about": "Software Development page and this is only for educational purposes.\n",
#     "category": "Software company",
#     "feed": {
#         "data": [
#             {
#                 "created_time": "2022-07-31T14:01:07+0000",
#                 "id": "112591734873647_112675964865224"
#             },
#             {
#                 "created_time": "2022-07-31T14:00:18+0000",
#                 "message": "endeavour for Education",
#                 "id": "112591734873647_112675578198596"
#             },
#             {
#                 "created_time": "2022-07-31T13:59:57+0000",
#                 "message": "study for education",
#                 "id": "112591734873647_112675381531949"
#             },
#             {
#                 "created_time": "2022-07-31T13:59:14+0000",
#                 "message": "software developer for educational purposes",
#                 "id": "112591734873647_112675074865313"
#             },
#             {
#                 "created_time": "2022-07-31T13:58:20+0000",
#                 "id": "112591734873647_112674528198701"
#             },
#             {
#                 "created_time": "2022-07-31T13:58:02+0000",
#                 "story": "My test page updated their cover photo.",
#                 "id": "112591734873647_112674431532044"
#             },
#             {
#                 "created_time": "2022-07-31T13:15:32+0000",
#                 "message": "beautiful fluffy cat",
#                 "id": "112591734873647_112647664868054"
#             },
#             {
#                 "created_time": "2022-07-31T13:15:10+0000",
#                 "message": "Let's read",
#                 "id": "112591734873647_112646858201468"
#             },
#             {
#                 "created_time": "2022-07-31T13:14:16+0000",
#                 "story": "My test page updated their profile picture.",
#                 "id": "112591734873647_112646468201507"
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "before": "",
#                 "after": ""
#             }
#         }
#     },
#     "posts": {
#         "data": [
#             {
#                 "created_time": "2022-07-31T14:01:07+0000",
#                 "id": "112591734873647_112675964865224"
#             },
#             {
#                 "created_time": "2022-07-31T14:00:18+0000",
#                 "message": "endeavour for Education",
#                 "id": "112591734873647_112675578198596"
#             },
#             {
#                 "created_time": "2022-07-31T13:59:57+0000",
#                 "message": "study for education",
#                 "id": "112591734873647_112675381531949"
#             },
#             {
#                 "created_time": "2022-07-31T13:59:14+0000",
#                 "message": "software developer for educational purposes",
#                 "id": "112591734873647_112675074865313"
#             },
#             {
#                 "created_time": "2022-07-31T13:58:20+0000",
#                 "id": "112591734873647_112674528198701"
#             },
#             {
#                 "created_time": "2022-07-31T13:58:02+0000",
#                 "story": "My test page updated their cover photo.",
#                 "id": "112591734873647_112674431532044"
#             },
#             {
#                 "created_time": "2022-07-31T13:15:32+0000",
#                 "message": "beautiful fluffy cat",
#                 "id": "112591734873647_112647664868054"
#             },
#             {
#                 "created_time": "2022-07-31T13:15:10+0000",
#                 "message": "Let's read",
#                 "id": "112591734873647_112646858201468"
#             },
#             {
#                 "created_time": "2022-07-31T13:14:16+0000",
#                 "story": "My test page updated their profile picture.",
#                 "id": "112591734873647_112646468201507"
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "before": "QVFIUnpsRVJ2WFI5NXplQnlWLVdzMDNoOGpMeTYtSHU2b1gxQmVJeFhIR0RHWVlRR0pZAVHdjUHZAWdW5CbkFrZAXNGZAEZAnaVhveWdxMVF0dXZAMQnJ5RTliWlhXX09ScndyZAjcwU2RrVkdEZAGR4VlJxc1VUaG5Gc1lORzczSnI0cVFOTVYz",
#                 "after": "QVFIUjBpMXFtYVM4eGhITmdqRlpQTVJzUDNWb1VoVS1KMERKYnNQa1dhUDVWT051YmtuaTZA0S0l0anV1eElKNUJTOV93WnVaQmJxN3I5V3hwbHlvaDF4X0RJRGJjeXVaaHJ2MERqeURDS3lydFB6RFJuVU0zNGF5dzhDU29OaGFSV1RQ"
#             }
#         }
#     },
#     "can_post": true,
#     "id": "112591734873647"
# }

# %%
### Getting metadata regarding each posts our test facebook page
### Showing each posts whether it is published and popular or not along with created time, promotion status etc

def main():
    token = ""
    graph = facebook.GraphAPI(token)
    post = graph.get_object('112591734873647', fields = "name,about,category,posts{is_published,is_popular,created_time,promotion_status}")
    print(json.dumps(post, indent = 4))
if __name__ == '__main__':
    main()
# Out:
# {
#     "name": "My test page",
#     "about": "Software Development page and this is only for educational purposes.\n",
#     "category": "Software company",
#     "posts": {
#         "data": [
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T14:01:07+0000",
#                 "promotion_status": "ineligible",
#                 "id": "112591734873647_112675964865224"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T14:00:18+0000",
#                 "promotion_status": "inactive",
#                 "id": "112591734873647_112675578198596"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:59:57+0000",
#                 "promotion_status": "inactive",
#                 "id": "112591734873647_112675381531949"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:59:14+0000",
#                 "promotion_status": "inactive",
#                 "id": "112591734873647_112675074865313"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:58:20+0000",
#                 "promotion_status": "ineligible",
#                 "id": "112591734873647_112674528198701"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:58:02+0000",
#                 "promotion_status": "ineligible",
#                 "id": "112591734873647_112674431532044"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:15:32+0000",
#                 "promotion_status": "inactive",
#                 "id": "112591734873647_112647664868054"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:15:10+0000",
#                 "promotion_status": "inactive",
#                 "id": "112591734873647_112646858201468"
#             },
#             {
#                 "is_published": true,
#                 "is_popular": false,
#                 "created_time": "2022-07-31T13:14:16+0000",
#                 "promotion_status": "ineligible",
#                 "id": "112591734873647_112646468201507"
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "before": "QVFIUnpsRVJ2WFI5NXplQnlWLVdzMDNoOGpMeTYtSHU2b1gxQmVJeFhIR0RHWVlRR0pZAVHdjUHZAWdW5CbkFrZAXNGZAEZAnaVhveWdxMVF0dXZAMQnJ5RTliWlhXX09ScndyZAjcwU2RrVkdEZAGR4VlJxc1VUaG5Gc1lORzczSnI0cVFOTVYz",
#                 "after": "QVFIUjBpMXFtYVM4eGhITmdqRlpQTVJzUDNWb1VoVS1KMERKYnNQa1dhUDVWT051YmtuaTZA0S0l0anV1eElKNUJTOV93WnVaQmJxN3I5V3hwbHlvaDF4X0RJRGJjeXVaaHJ2MERqeURDS3lydFB6RFJuVU0zNGF5dzhDU29OaGFSV1RQ"
#             }
#         }
#     },
#     "id": "112591734873647"
# }

# %% [markdown]
# ### Fetching Data about ads campaign

# %%
import facebook
import json

# %%
def main():
    token = "EAAKoAQmcz7cBAHu1aneffZC8ae0oZA3uS5uaJvPyBtw4YZCYHw7FLd6ZBNsdsItQngB5dNLxiEmCH01FvZCqWRIxbvPazQAPMz7aYscDRS17E0h0IsLRmQ0Ru29tecz5XGLLhvMlPnDzZC4eMR1nCIDHAdSwwLvhQZBCu7BTnjFulmlmWbLVp3b"
    graph = facebook.GraphAPI(token)
    post = graph.get_object('me', fields = "id,name,adaccounts")
    print(json.dumps(post, indent = 4))
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# Input In [19], in <cell line: 6>()
#       5     print(json.dumps(post, indent = 4))
#       6 if __name__ == '__main__':
# ----> 7     main()
#
# Input In [19], in main()
#       2 token = "EAAKoAQmcz7cBAHu1aneffZC8ae0oZA3uS5uaJvPyBtw4YZCYHw7FLd6ZBNsdsItQngB5dNLxiEmCH01FvZCqWRIxbvPazQAPMz7aYscDRS17E0h0IsLRmQ0Ru29tecz5XGLLhvMlPnDzZC4eMR1nCIDHAdSwwLvhQZBCu7BTnjFulmlmWbLVp3b"
#       3 graph = facebook.GraphAPI(token)
# ----> 4 post = graph.get_object('me', fields = "id,name,adaccounts")
#       5 print(json.dumps(post, indent = 4))
#
# File ~/anaconda3/lib/python3.9/site-packages/facebook/__init__.py:126, in GraphAPI.get_object(self, id, **args)
#     124 def get_object(self, id, **args):
#     125     """Fetches the given object from the graph."""
# --> 126     return self.request("{0}/{1}".format(self.version, id), args)
#
# File ~/anaconda3/lib/python3.9/site-packages/facebook/__init__.py:313, in GraphAPI.request(self, path, args, post_args, files, method)
#     310     raise GraphAPIError("Maintype was not text, image, or querystring")
#     312 if result and isinstance(result, dict) and result.get("error"):
# --> 313     raise GraphAPIError(result)
#     314 return result
#
# GraphAPIError: (#2635) You are calling a deprecated version of the Ads API. Please update to the latest version: v14.0.
